# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('image0.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
